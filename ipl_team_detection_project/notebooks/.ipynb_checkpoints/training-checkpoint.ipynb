# %%
from src.dataset_builder import DatasetBuilder
from src.train import TeamClassifierTrainer

builder = DatasetBuilder('../master_csv.csv')

X, y = builder.build_dataset()

trainer = TeamClassifierTrainer()

trainer.train(X, y)
